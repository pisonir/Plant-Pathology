# %%
import pandas as pd

# %%
df_train = pd.read_csv('./train.csv')

# %%
df_train.head()
# Out:
#   image_id  healthy  multiple_diseases  rust  scab
# 0  Train_0        0                  0     0     1
# 1  Train_1        0                  1     0     0
# 2  Train_2        1                  0     0     0
# 3  Train_3        0                  0     1     0
# 4  Train_4        1                  0     0     0

# %%
img_id = df_train.iloc[:,0]
img_id
# Out:
# 0          Train_0
# 1          Train_1
# 2          Train_2
# 3          Train_3
# 4          Train_4
#            ...
# 1816    Train_1816
# 1817    Train_1817
# 1818    Train_1818
# 1819    Train_1819
# 1820    Train_1820
# Name: image_id, Length: 1821, dtype: object

# %%
labels = df_train.iloc[:,1:]
labels
# Out:
#       healthy  multiple_diseases  rust  scab
# 0           0                  0     0     1
# 1           0                  1     0     0
# 2           1                  0     0     0
# 3           0                  0     1     0
# 4           1                  0     0     0
# ...       ...                ...   ...   ...
# 1816        0                  0     0     1
# 1817        1                  0     0     0
# 1818        1                  0     0     0
# 1819        0                  0     1     0
# 1820        0                  0     0     1
#
# [1821 rows x 4 columns]

# %%
print('Image name: {}'.format(img_id))
print('Labels shape: {}'.format(labels.shape))
print('First 4 Labels: {}'.format(labels[:4]))
# Out:
# Image name: 0          Train_0
# 1          Train_1
# 2          Train_2
# 3          Train_3
# 4          Train_4
#            ...
# 1816    Train_1816
# 1817    Train_1817
# 1818    Train_1818
# 1819    Train_1819
# 1820    Train_1820
# Name: image_id, Length: 1821, dtype: object
# Labels shape: (1821, 4)
# First 4 Labels:    healthy  multiple_diseases  rust  scab
# 0        0                  0     0     1
# 1        0                  1     0     0
# 2        1                  0     0     0
# 3        0                  0     1     0

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
from Project import project
from data import MyDataset
from utils import show,show_dataset
from data.transformation import test_transform,train_transform
import matplotlib.pyplot as plt

ds = MyDataset(project.base_dir / 'train.csv', project.dataset_dir / 'train', transform=train_transform)

# %%
show_dataset(ds)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import main
main()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to C:\Users\ricca/.cache\torch\checkpoints\resnet18-5c106cde.pth
# 100%|█████████████████████████████████████████████████████████████████████████████| 44.7M/44.7M [00:09<00:00, 4.92MB/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-afc3a69f408e> in <module>
#       1 import main
# ----> 2 main()
#
# TypeError: 'module' object is not callable

# %%
main
# Out:
# <module 'main' from 'C:\\Users\\ricca\\Documents\\Github\\Plant-Pathology\\main.py'>

# %%
import torch

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
device
# Out:
# 'cuda'

# %%
torch.cuda.is_available()
# Out:
# True
